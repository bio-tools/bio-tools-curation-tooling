# %%
import json, re, requests
import os
import copy
import csv
from datetime import date
import settings
from importlib import reload
reload(settings)
from settings import http_settings, file_settings


# This function can be used for the first time on to_biotools.json output from Pub2tools
# as well as it can be rerun on the preprints json in the future to check for new publications
# if there are new publications in low_tools_prp_date.json file, they will be removed from this file
# and moved to the publications file

# %%
WRITE_TO_DB = False
to_curate = 100 #how many of high_tools to write to csv file to be manually curated (int or str) ('all')

# %% [markdown]
# Check if all files are available

# %%
json_file = (file_settings['path_to_pub2tools_month'] + '/' + file_settings['json_tools']).replace('//', '/')
if not(os.path.exists(json_file) and os.path.isfile(json_file)):
    print("can't find json tools file")

# %%
pub2tools_file=(file_settings['path_to_pub2tools_month'] + '/' + file_settings['pub2tools_log']).replace('//', '/')  #check if log file exists in output folder
if not(os.path.exists(pub2tools_file) and os.path.isfile(pub2tools_file)):
    print("can't find pub2tools log file")

# %%
preprints_file=file_settings['preprints_path'] 
if not(os.path.exists(preprints_file) and os.path.isfile(preprints_file)):
    print("can't find pub2tools log file")

# %%
lowtools_file=file_settings['lowtools_path'] 
if not(os.path.exists(lowtools_file) and os.path.isfile(lowtools_file)):
    print("can't find pub2tools log file")

# %% [markdown]
# ## Process_scrap workflow

# %% [markdown]
# Get token for further validation

# %%
def login_prod(http_settings):
    headers_token = {
        'Content-Type': 'application/json'
        }
    user = json.dumps({
        'username': http_settings['username'],
        'password': http_settings['password']
    })

    token_r = requests.post(http_settings['host_prod'] + http_settings['login'] + http_settings['json'], headers=headers_token, data=user)
    token = json.loads(token_r.text)['key']
    return token

# %% [markdown]
# Process Pub2tools output (only high tools)

# %%
def process_tools(json_file):
    high_tools = []
    with open(json_file) as jf:
        data = json.load(jf)
        tools = data['list']
        for tool in tools:
        #    tool['confidence_flag'] = confidence_dict[tool['name']].replace('_',' ')
            tool['editPermission'] = {'type': 'public'}
        
            biotoolsID = re.sub('[^a-zA-Z0-9_~ .-]*', '',tool['name'])
            biotoolsID = re.sub('[ ]+','-', biotoolsID)
            biotoolsID = 'pub2tools2023__' + biotoolsID
            tool['biotoolsID'] = biotoolsID.lower()

            if tool['confidence_flag'].lower() == 'high':
                #tool['date']= check_date(pub2tools_file)
                url_d='{d}{bt}'.format(d=http_settings['dev'],bt=tool['biotoolsID'])  #create tool_link
                tool['tool_link']=url_d
                high_tools.append(tool)
    return high_tools

# %% [markdown]
# Validate processed tools

# %%
def validate_tool(tool, token, http_settings):
    url = '{h}{t}{v}{f}'.format(h=http_settings['host_prod'], t=http_settings['tool'],v=http_settings['validate'], f=http_settings['json'])   
    headers = {
        'Content-Type': 'application/json',
        'Authorization': 'Token ' + token
    }

    r = requests.post(url, headers=headers, data=json.dumps(tool))
    if r.status_code >= 200 and r.status_code <= 299:
        return (True, r.text)
    return (False, r.text)

# %%
def validate_tools(tools, token, http_settings):
    tools_count = len(tools)
    to_add = []
    problem_tools = []    
    for tool in tools: 
        print(tool['confidence_flag'])
        (valid, txt) = validate_tool(tool, token, http_settings)
        #valid=True   #For testing
        if valid:  
            to_add.append(tool)            
            print("Tool with name {name} is valid.".format(name=tool['name']))
        else:
            print("Tool with name:{name} has the errors: {errors}".format(name=tool['name'],errors=txt))
            print('Checking if there is an error with the name {name} ... '.format(name=tool['name']))
            if (is_html_error(txt)):
                print("It's an html error message ... ")
            else:
                e = json.loads(txt)
                if type(e) is dict and e.get('name') != None:
                    print('There is an error with the name {name}'.format(name=tool['name']))
                    tool_temp = copy.deepcopy(tool)
                    tool_temp['name'] = tool_temp['name'] + '_autogenerated'
                    print('Trying to fix problem by changing tool name to {name}'.format(name=tool_temp['name']))
                    (valid, txt) = validate_tool(tool_temp, token, http_settings)
                    if valid:
                        print('The error was fixed by changing the name to {name}'.format(name=tool_temp['name']))
                        tool['name'] = tool_temp['name']
                        to_add.append(tool)            
                    else:
                        print('The error could not be fixed')
                        problem_tools.append({'tool_name':tool['name'],'error':txt})
                else:
                    print('There was a different error')
                    problem_tools.append({'tool_name':tool['name'],'error':txt})
        print('-----------------')       
    print("Total tools validated: {added} out of a total of: {total} ".format(added=len(to_add), total=tools_count))
    if len(problem_tools) > 0:
        print("{problem} tools with problems:".format(problem=len(problem_tools)))
        print(problem_tools)
    else:
        print("No tools with problems")
    return to_add

# %%
def is_html_error(message):
    return '<html' in message.lower() or '<body' in message.lower()

# %% [markdown]
# Check for preprints among validated, and check file with all preprints

# %%
def identify_preprints(tools, json_file):
    new_pubs=[]
    for tool in tools:
        url_pub,is_preprint=identify_preprint(tool)
        tool['publication_link']=url_pub
        tool['is_preprint']=is_preprint
        if not is_preprint:
            new_pubs.append(tool)
    print(new_pubs)
    print("There are {preprints} preprints and {pubs} pubs in tools".format(pubs=len(new_pubs), preprints=len(tools)-len(new_pubs)))
    with open(json_file, 'r') as prp_json_file:
        preprints = json.load(prp_json_file)
    tools_prp = preprints['list']
    number_of_pp=len(tools_prp)
    print("There are {preprints} preprints in the json file. Checking if something was published.....".format(preprints=number_of_pp))
    updated_pubs=[]
    for tool in tools_prp:
        url_pub,is_preprint=identify_preprint(tool)
        tool['publication_link']=url_pub
        tool['is_preprint']=is_preprint
        if not is_preprint:
            updated_pubs.append(tool)
    print(updated_pubs)
    print("There are {published} published tools in the json file. ".format(published=len(updated_pubs)))
    print("Updating json.....")
    to_upload = updated_pubs + new_pubs #First newly published preprints, then tools from current month
    #preprints.extend(updated_pubs)
        #pub_json = {"count":len(pubs),"list":pubs}
    preprints_new = [tool for tool in tools if tool not in new_pubs]
    preprints_old = [tool for tool in tools_prp if tool not in updated_pubs]
    preprints_data = preprints_old + preprints_new
    pp_json = {"count":len(preprints_data),"list":preprints_data}
    with open(json_file, 'w') as preprints_json_file:
            json.dump(pp_json, preprints_json_file, indent=4)
    number_of_pp=sum(1 for tool in tools if tool.get('is_preprint') == True)
    print("There are {preprints} preprints in the file after identification".format(preprints=number_of_pp))
    return to_upload

# %%
def search_europe_pmc(query):
    """Search Europe PMC and return the JSON response."""
    api_endpoint = "https://www.ebi.ac.uk/europepmc/webservices/rest/search"
    params = {
        'query': query,
        'format': 'json',
        'resultType': 'core'
    }
    response = requests.get(api_endpoint, params=params)
    if response.status_code == 200:
        return response.json()
    else:
        return None

# %%
def identify_preprint(tool):
    """
    Identify if a publication associated with a tool is a preprint.
    Args:
    - tool (dict): A dictionary containing tool metadata (Pub2Tools output).
    Returns:
    - pub_link (str): A link to the publication.
    - is_preprint (bool): True if the publication is a preprint, False otherwise.
    """
    if 'doi' in tool['publication'][0]:
        # Extract DOI from publication metadata if exists
        doi=tool['publication'][0]['doi']
        print(tool['name'])
        data = search_europe_pmc(f'DOI:"{doi}"')        
        if data.get('hitCount', 0) != 0:  # If DOI is found in Europe PMC database
            result=data['resultList']['result'] 
            if (result[0].get('source')=='PPR' and result[0].get('commentCorrectionList') is None): # Check if the source is PPR and there are no comment corrections
                is_preprint=True
                pub_link= f"https://doi.org/{doi}"
            elif (result[0].get('source')=='PPR' and result[0].get('commentCorrectionList') is not None): 
                if (result[0].get('commentCorrectionList').get('commentCorrection')[0].get('source')=='PPR'): # Check if the first comment correction source is PPR
                    is_preprint=True
                    pub_link= f"https://doi.org/{doi}"
                else:  # Extract external ID and search for potential match
                    ext_id=result[0].get('commentCorrectionList').get('commentCorrection')[0].get('id')
                    potential_match=search_europe_pmc(f'ext_id:"{ext_id}" NOT DOI:"{doi}"')
                    if potential_match or potential_match.get('hitCount', 0) != 0:
                        tool.pop('publication')
                        pubs={}
                        if ('doi' in potential_match['resultList']['result'][0].keys()):
                            new_doi=potential_match['resultList']['result'][0]['doi']
                            pubs['doi']=new_doi
                            pub_link= f"https://doi.org/{new_doi}"
                            print("Tool {name} has a published version. Changing from {doi} to {new_doi} ".format(name=tool['name'], doi=doi, new_doi=new_doi))
                        if ('pmid' in potential_match['resultList']['result'][0].keys()): 
                            new_pmid = potential_match['resultList']['result'][0]['pmid']
                            pub_link = f"https://pubmed.ncbi.nlm.nih.gov/{new_pmid}/" 
                            pubs['pmid'] = new_pmid
                            print("Tool {name} has a published version. Changing from {doi} to {pmid} ".format(name=tool['name'], doi=doi, pmid=new_pmid))   
                        if ('pmcid' in potential_match['resultList']['result'][0].keys()):
                            new_pmcid = potential_match['resultList']['result'][0]['pmcid']
                            pubs['pmcid'] = new_pmcid 
                        tool['publication']=[pubs]
                        is_preprint=False
                    else:  # If there is no match in a database (even though there is correction list), we can't say much about it
                        is_preprint=True
                        pub_link= f"https://doi.org/{doi}"
            else:   # Source is other than preprint, that's always publication (?)
                pub_link= f"https://doi.org/{doi}"
                is_preprint=False

        else:  #No result in Europe PMC database
            pub_link= f"https://doi.org/{doi}"
            is_preprint=False  #Is it better to assume that this is preprint or not preprint? 
    else:
        print("There is no DOI for this tool")
        pmid=tool['publication'][0]['pmid']
        pub_link= f"https://pubmed.ncbi.nlm.nih.gov/{pmid}/" 
        # It can still be preprint, but it's safer to assume it's not and double-check it with curation.  
        is_preprint=False
    return pub_link, is_preprint

# %% [markdown]
# From tools that are not preprints, create curation csv_file of first TO_CURATE tools

# %%
def generate_csv_pub(tools,to_curate):
    publications = []
    if to_curate=='all':
        for tool in tools:
            if not tool['is_preprint']:
                publications.append(tool)
    else:
        counter = 0
        for tool in tools:
            if not tool['is_preprint']:
                publications.append(tool)
                counter += 1
                if counter == to_curate:
                    break
    file_date=check_date(pub2tools_file)  #function to return date
    file_name='pub2tools_{year}_{month}.csv'.format(year=file_date[0],month=file_date[1]) #name .csv file
    print(" Writing {to_curate} files which is {pubs} publications to a {filename} ".format(to_curate=to_curate, pubs=len(publications), filename=file_name))
    with open(file_name,'w') as fileobj: #write to .csv file
        writerobj=csv.writer(fileobj)
        writerobj.writerow(['tool_link','tool_name','homepage','publication_link'])
        for tool in publications:
            writerobj.writerow([tool['tool_link'],tool['name'],tool['homepage'],tool['publication_link']])
    leftover_tools=[tool for tool in tools if tool not in publications]
    tools_to_add=publications
    return tools_to_add, leftover_tools

# %% [markdown]
# For naming csv file

# %%
def check_date(pub2tools_file):     #function to generate date
    log_file=open(pub2tools_file,'r')
    textfile=log_file.read()
    log_file.close()
    date=re.findall("--month (\d+)-(\d+)",textfile)  #from command for pub2tools
    return date[0]

# %% [markdown]
# Update json for all of the low, published tools

# %%
def generate_json(tools, lowtools_file):
    #low_tools = {"count":len(tools),"list":tools}
    with open(json_file, 'r') as lowtools_json_file:
        lowtools = json.load(lowtools_json_file)
    tools_low = lowtools['list']
    tools_update =tools_low + tools
    lowtools_json = {"count":len(tools_update),"list":tools_update}
    with open(lowtools_file, 'w') as low_tools_json_file:
        json.dump(lowtools_json, low_tools_json_file, indent=4)

# %%
def add_tools(tools, token, http_settings, WRITE_TO_DB):
    print(WRITE_TO_DB)
    if not(WRITE_TO_DB):
        print("Write flag is False, exiting...")
        return    
    url = '{h}{t}{f}'.format(h=http_settings['host_prod'], t=http_settings['tool'], f=http_settings['json'])
    headers = {
        'Content-Type': 'application/json',
        'Authorization': 'Token ' + token
    }
    tools_count = len(tools)
    problem_tools = []
    ok_tools = 0
    for tool in tools:
        r = requests.post(url, headers=headers, data=json.dumps(tool))
        
        if r.status_code >= 200 and r.status_code <= 299:
            print(tool['biotoolsID'], 'Added', r.status_code)
            ok_tools += 1
        else:
            print("An Error:",tool['biotoolsID'], r.text)
            problem_tools.append({'tool_id':tool['biotoolsID'],'error':r.text})
        print('--------------')
        time.sleep(2)

            
    print("Total tools added: {added} out of a total of: {total} ".format(added=ok_tools, total=tools_count))
    if len(problem_tools) > 0:
        print("{problem} tools with problems:".format(problem=len(problem_tools)))
        print(problem_tools)
    else:
        print("No tools with problems")

# %%
tools = process_tools(json_file)                        # STEP 1. READ PUB2TOOLS OUTPUT JSON FILE

# %%
token = login_prod(http_settings)                       # STEP 2. GET TOKEN

# %%
tools_v = validate_tools(tools, token, http_settings)   # STEP 3. VALIDATE TOOLS FROM PUB2TOOLS OUTPUT
# Out:
# high
# Tool with name Motifizer is valid.
# -----------------
# high
# Tool with name CanSig is valid.
# -----------------
# high
# Tool with name CoDMI is valid.
# -----------------
# high
# Tool with name:PPVED has the errors: {"function":[{"operation":[{},{},{},{"general_errors":["Invalid URI: http://edamontology.org/operation_3923."]}]}]}
# Checking if there is an error with the name PPVED ...
# There was a different error
# -----------------
# high
# Tool with name HGDTI is valid.
# -----------------
# high
# Tool with name KDmarkers is valid.
# -----------------
# high
# Tool with name HiCHub is valid.
# -----------------
# high
# Tool with name TIGER is valid.
# -----------------
# high
# Tool with name IsoAligner is valid.
# -----------------
# high
# Tool with name:RNAinsecta has the errors: {"biotoolsID":["A resource with this ID already exists. bio.tools IDs need to be unique"]}
# Checking if there is an error with the name RNAinsecta ...
# There was a different error
# -----------------
# high
# Tool with name:CACSV has the errors: {"biotoolsID":["A resource with this ID already exists. bio.tools IDs need to be unique"]}
# Checking if there is an error with the name CACSV ...
# There was a different error
# -----------------
# high
# Tool with name SiCoDEA is valid.
# -----------------
# high
# Tool with name:Rye has the errors: {"biotoolsID":["A resource with this ID already exists. bio.tools IDs need to be unique"]}
# Checking if there is an error with the name Rye ...
# There was a different error
# -----------------
# high
# Tool with name OGAR is valid.
# -----------------
# high
# Tool with name SHARCQ is valid.
# -----------------
# high
# Tool with name ASTool is valid.
# -----------------
# high
# Tool with name IMPatienT is valid.
# -----------------
# high
# Tool with name TB-Net is valid.
# -----------------
# high
# Tool with name EcoFun-MAP is valid.
# -----------------
# high
# Tool with name SageNet is valid.
# -----------------
# high
# Tool with name:DEPP has the errors: {"biotoolsID":["A resource with this ID already exists. bio.tools IDs need to be unique"]}
# Checking if there is an error with the name DEPP ...
# There was a different error
# -----------------
# high
# Tool with name CLIN-X is valid.
# -----------------
# high
# Tool with name DeepDNAbP is valid.
# -----------------
# high
# Tool with name Methylartist is valid.
# -----------------
# high
# Tool with name RLTLBO is valid.
# -----------------
# high
# Tool with name BANYAN is valid.
# -----------------
# high
# Tool with name AttentionDTA is valid.
# -----------------
# high
# Tool with name MDGNN is valid.
# -----------------
# high
# Tool with name CRISPRedict is valid.
# -----------------
# high
# Tool with name PolypSeg+ is valid.
# -----------------
# high
# Tool with name m5Cpred-XS is valid.
# -----------------
# high
# Tool with name ImmuMethy is valid.
# -----------------
# high
# Tool with name MicrobioSee is valid.
# -----------------
# high
# Tool with name SEACells is valid.
# -----------------
# high
# Tool with name fastman is valid.
# -----------------
# high
# Tool with name AutoScore-Imbalance is valid.
# -----------------
# high
# Tool with name ASQ is valid.
# -----------------
# high
# Tool with name:OptDesign has the errors: {"function":[{"operation":[{"general_errors":["Invalid URI: http://edamontology.org/operation_3939."]},{},{}]}]}
# Checking if there is an error with the name OptDesign ...
# There was a different error
# -----------------
# high
# Tool with name RetroSnake is valid.
# -----------------
# high
# Tool with name ToxPi is valid.
# -----------------
# high
# Tool with name:DeepSARS has the errors: {"function":[{"operation":[{"general_errors":["Invalid URI: http://edamontology.org/operation_3923."]},{},{},{},{}]}]}
# Checking if there is an error with the name DeepSARS ...
# There was a different error
# -----------------
# high
# Tool with name:StORF-Reporter has the errors: {"biotoolsID":["A resource with this ID already exists. bio.tools IDs need to be unique"]}
# Checking if there is an error with the name StORF-Reporter ...
# There was a different error
# -----------------
# high
# Tool with name scAEGAN is valid.
# -----------------
# high
# Tool with name DeepBtoD is valid.
# -----------------
# high
# Tool with name Neuroscout is valid.
# -----------------
# high
# Tool with name GlycoQL is valid.
# -----------------
# high
# Tool with name:ARBRE has the errors: {"function":[{"operation":[{},{},{},{"general_errors":["Invalid URI: http://edamontology.org/operation_3939."]}]}]}
# Checking if there is an error with the name ARBRE ...
# There was a different error
# -----------------
# high
# Tool with name RustNet is valid.
# -----------------
# high
# Tool with name SmGDB is valid.
# -----------------
# high
# Tool with name Onlinemeta is valid.
# -----------------
# high
# Tool with name SISS-Geo is valid.
# -----------------
# high
# Tool with name TITAN is valid.
# -----------------
# high
# Tool with name TubULAR is valid.
# -----------------
# high
# Tool with name HiveRel is valid.
# -----------------
# high
# Tool with name ROADMAPS is valid.
# -----------------
# high
# Tool with name SNARER is valid.
# -----------------
# high
# Tool with name E2Style is valid.
# -----------------
# high
# Tool with name OC_Finder is valid.
# -----------------
# high
# Tool with name citationchaser is valid.
# -----------------
# high
# Tool with name Spiky is valid.
# -----------------
# high
# Tool with name surge is valid.
# -----------------
# high
# Tool with name ZZS similarity tool is valid.
# -----------------
# high
# Tool with name BANKSY is valid.
# -----------------
# high
# Tool with name Pocket2Drug is valid.
# -----------------
# high
# Tool with name IPOscore is valid.
# -----------------
# high
# Tool with name TCR-L is valid.
# -----------------
# high
# Tool with name epiAneufinder is valid.
# -----------------
# high
# Tool with name Rizoma is valid.
# -----------------
# high
# Tool with name MOOD is valid.
# -----------------
# high
# Tool with name ClinicaDL is valid.
# -----------------
# high
# Tool with name DF-SSmVEP is valid.
# -----------------
# high
# Tool with name hemispheR is valid.
# -----------------
# high
# Tool with name MainSEL is valid.
# -----------------
# high
# Tool with name GenMPI is valid.
# -----------------
# high
# Tool with name RRGP is valid.
# -----------------
# high
# Tool with name COPILOT is valid.
# -----------------
# high
# Tool with name iCatcher is valid.
# -----------------
# high
# Tool with name COVID-19-associated ARDS non-viral ARDS is valid.
# -----------------
# high
# Tool with name AutoDesigner is valid.
# -----------------
# high
# Tool with name MILNP is valid.
# -----------------
# high
# Tool with name PeakVI is valid.
# -----------------
# high
# Tool with name DTSyn is valid.
# -----------------
# high
# Tool with name LinQ-View is valid.
# -----------------
# high
# Tool with name WalkIm is valid.
# -----------------
# high
# Tool with name PhenoBERT is valid.
# -----------------
# high
# Tool with name CPIELA is valid.
# -----------------
# high
# Tool with name:LANDMark has the errors: {"function":[{"operation":[{"general_errors":["Invalid URI: http://edamontology.org/operation_3923."]},{},{}]}]}
# Checking if there is an error with the name LANDMark ...
# There was a different error
# -----------------
# high
# Tool with name PCRMS is valid.
# -----------------
# high
# Tool with name:Boquila has the errors: {"biotoolsID":["A resource with this ID already exists. bio.tools IDs need to be unique"]}
# Checking if there is an error with the name Boquila ...
# There was a different error
# -----------------
# high
# Tool with name MPI-GWAS is valid.
# -----------------
# high
# Tool with name:PyMiner has the errors: {"function":[{"operation":[{},{},{},{"general_errors":["Invalid URI: http://edamontology.org/operation_3939."]}]}]}
# Checking if there is an error with the name PyMiner ...
# There was a different error
# -----------------
# high
# Tool with name MAPPER is valid.
# -----------------
# high
# Tool with name DeepTMHMM is valid.
# -----------------
# high
# Tool with name DeSmoke-LAP is valid.
# -----------------
# high
# Tool with name MAECI is valid.
# -----------------
# high
# Tool with name MetaRelSubNetVis is valid.
# -----------------
# high
# Tool with name Read2Tree is valid.
# -----------------
# high
# Tool with name PregTox is valid.
# -----------------
# high
# Tool with name GEAR is valid.
# -----------------
# high
# Tool with name CANon is valid.
# -----------------
# high
# Tool with name AI4ACP is valid.
# -----------------
# high
# Tool with name:PipeCoV has the errors: {"function":[{"operation":[{},{"general_errors":["Invalid URI: http://edamontology.org/operation_3923."]},{}]}]}
# Checking if there is an error with the name PipeCoV ...
# There was a different error
# -----------------
# high
# Tool with name PredNitro is valid.
# -----------------
# high
# Tool with name scTSSR2 is valid.
# -----------------
# high
# Tool with name ENDS assumptions is valid.
# -----------------
# high
# Tool with name PanGu Drug Model is valid.
# -----------------
# high
# Tool with name:Phertilizer has the errors: {"biotoolsID":["A resource with this ID already exists. bio.tools IDs need to be unique"]}
# Checking if there is an error with the name Phertilizer ...
# There was a different error
# -----------------
# high
# Tool with name recolorize is valid.
# -----------------
# high
# Tool with name Fast-Higashi is valid.
# -----------------
# high
# Tool with name KMSubtraction is valid.
# -----------------
# high
# Tool with name LIPSHOK is valid.
# -----------------
# high
# Tool with name AJILE12 is valid.
# -----------------
# high
# Tool with name MASI is valid.
# -----------------
# high
# Tool with name BiGAMi is valid.
# -----------------
# high
# Tool with name nsink is valid.
# -----------------
# high
# Tool with name TransPhos is valid.
# -----------------
# high
# Tool with name Kalmag is valid.
# -----------------
# high
# Tool with name CSR-Net is valid.
# -----------------
# high
# Tool with name RFPDR is valid.
# -----------------
# high
# Tool with name SSPNet is valid.
# -----------------
# high
# Tool with name FollicleFinder is valid.
# -----------------
# high
# Tool with name ceCLC is valid.
# -----------------
# high
# Tool with name EEG MEG is valid.
# -----------------
# high
# Tool with name CIGER is valid.
# -----------------
# high
# Tool with name MLHC-COVID-19 is valid.
# -----------------
# high
# Tool with name CPA-PM is valid.
# -----------------
# high
# Tool with name Gradient-k is valid.
# -----------------
# high
# Tool with name gACSON is valid.
# -----------------
# high
# Tool with name Aegypti-Atlas is valid.
# -----------------
# high
# Tool with name Psitrum is valid.
# -----------------
# high
# Tool with name MISS is valid.
# -----------------
# high
# Tool with name mHealth literacy mHealth literacy is valid.
# -----------------
# high
# Tool with name Gifsy-1 artAB gogB is valid.
# -----------------
# high
# Tool with name DeepDynaTree is valid.
# -----------------
# high
# Tool with name IETIF is valid.
# -----------------
# high
# Tool with name multiplestressR is valid.
# -----------------
# high
# Tool with name TSFD-Net is valid.
# -----------------
# high
# Tool with name STKD is valid.
# -----------------
# high
# Tool with name LuminoCell is valid.
# -----------------
# high
# Tool with name:DeePiCt has the errors: {"biotoolsID":["A resource with this ID already exists. bio.tools IDs need to be unique"]}
# Checking if there is an error with the name DeePiCt ...
# There was a different error
# -----------------
# high
# Tool with name covid-cancer is valid.
# -----------------
# high
# Tool with name SemanticCAP is valid.
# -----------------
# high
# Tool with name GII 2P16 GII 4P16 noroviruses is valid.
# -----------------
# high
# Tool with name DFLM is valid.
# -----------------
# high
# Tool with name TCSP is valid.
# -----------------
# high
# Tool with name AHLS-pred is valid.
# -----------------
# high
# Tool with name funRiceGenes is valid.
# -----------------
# high
# Tool with name CVVB is valid.
# -----------------
# high
# Tool with name SGP is valid.
# -----------------
# high
# Tool with name NEUROeSTIMator is valid.
# -----------------
# high
# Tool with name SE-BLTCNN is valid.
# -----------------
# high
# Tool with name SOKS is valid.
# -----------------
# high
# Tool with name MANNERS-DB is valid.
# -----------------
# high
# Tool with name RLSDSPCA is valid.
# -----------------
# high
# Tool with name CEBA is valid.
# -----------------
# high
# Tool with name RPfam is valid.
# -----------------
# high
# Tool with name FastDMF is valid.
# -----------------
# high
# Tool with name sponge gourd watermelon is valid.
# -----------------
# high
# Tool with name U-RISC is valid.
# -----------------
# high
# Tool with name DWPPI is valid.
# -----------------
# high
# Tool with name CPGL is valid.
# -----------------
# high
# Tool with name Sophora flavescens Kushen decoction is valid.
# -----------------
# high
# Tool with name MetaDR is valid.
# -----------------
# high
# Tool with name GMM-NEA is valid.
# -----------------
# high
# Tool with name TurboBC is valid.
# -----------------
# high
# Tool with name DiaNat-DB is valid.
# -----------------
# high
# Tool with name COVID-19 non-COVID-19 wards Sudan Zambia is valid.
# -----------------
# high
# Tool with name sup- sup is valid.
# -----------------
# high
# Tool with name SPHARM-Net is valid.
# -----------------
# high
# Tool with name:ShrinkCRISPR has the errors: {"biotoolsID":["A resource with this ID already exists. bio.tools IDs need to be unique"]}
# Checking if there is an error with the name ShrinkCRISPR ...
# There was a different error
# -----------------
# high
# Tool with name:SAM has the errors: {"biotoolsID":["A resource with this ID already exists. bio.tools IDs need to be unique"]}
# Checking if there is an error with the name SAM ...
# There was a different error
# -----------------
# high
# Tool with name WFA-GPU is valid.
# -----------------
# high
# Tool with name HergSPred is valid.
# -----------------
# high
# Tool with name A3D database is valid.
# -----------------
# high
# Tool with name ingrained is valid.
# -----------------
# high
# Tool with name Research COVID-19 air pollution is valid.
# -----------------
# high
# Tool with name rheuma2025 is valid.
# -----------------
# high
# Tool with name FateCompass is valid.
# -----------------
# high
# Tool with name CoMI is valid.
# -----------------
# high
# Tool with name Biocode is valid.
# -----------------
# high
# Tool with name FRET-lines is valid.
# -----------------
# high
# Tool with name scMM is valid.
# -----------------
# high
# Tool with name DNE is valid.
# -----------------
# high
# Tool with name Movement Disorders is valid.
# -----------------
# high
# Tool with name eGRM is valid.
# -----------------
# high
# Tool with name AIM is valid.
# -----------------
# high
# Tool with name TMJOAI is valid.
# -----------------
# high
# Tool with name PADF is valid.
# -----------------
# high
# Tool with name SIMUS is valid.
# -----------------
# high
# Tool with name MISP SRH is valid.
# -----------------
# high
# Tool with name Telerehabilitation physical disabilities movement impairment is valid.
# -----------------
# high
# Tool with name Cure VCP Scientific Conference 2021 is valid.
# -----------------
# high
# Tool with name Gegen Qinlian Decoction is valid.
# -----------------
# high
# Tool with name MANE is valid.
# -----------------
# high
# Tool with name PicassoNet is valid.
# -----------------
# high
# Tool with name:QuasiFlow has the errors: {"biotoolsID":["A resource with this ID already exists. bio.tools IDs need to be unique"]}
# Checking if there is an error with the name QuasiFlow ...
# There was a different error
# -----------------
# high
# Tool with name P-FLUX is valid.
# -----------------
# high
# Tool with name BCOVIDOA is valid.
# -----------------
# high
# Tool with name BiWFA is valid.
# -----------------
# high
# Tool with name GDLPA is valid.
# -----------------
# high
# Tool with name:UMIcountR has the errors: {"function":[{"operation":[{"general_errors":["Invalid URI: http://edamontology.org/operation_3923."]},{},{},{}]}]}
# Checking if there is an error with the name UMIcountR ...
# There was a different error
# -----------------
# high
# Tool with name iVp iLAE iBF is valid.
# -----------------
# high
# Tool with name switchable CycleGAN is valid.
# -----------------
# high
# Tool with name la readmision por deshidratacion tanto is valid.
# -----------------
# high
# Tool with name MaxSpliZer is valid.
# -----------------
# high
# Tool with name KDM4B is valid.
# -----------------
# high
# Tool with name Antilogic is valid.
# -----------------
# high
# Tool with name HisCoM-Kernel is valid.
# -----------------
# high
# Tool with name subN LiBasub3 subN NaBasub3 subN is valid.
# -----------------
# high
# Tool with name fern phylogeny is valid.
# -----------------
# high
# Tool with name AB-DB is valid.
# -----------------
# high
# Tool with name SOAR is valid.
# -----------------
# high
# Tool with name TurboBFS is valid.
# -----------------
# high
# Tool with name NVivo is valid.
# -----------------
# high
# Tool with name SARS-ANI is valid.
# -----------------
# high
# Tool with name TWIENG is valid.
# -----------------
# high
# Tool with name ConfoundR is valid.
# -----------------
# high
# Tool with name MuLHiTA is valid.
# -----------------
# high
# Tool with name TAGNet is valid.
# -----------------
# high
# Tool with name HFP-QSMGAN is valid.
# -----------------
# high
# Tool with name LightIoT is valid.
# -----------------
# high
# Tool with name AsgeneDB is valid.
# -----------------
# high
# Tool with name LEV4REC is valid.
# -----------------
# high
# Tool with name VIGIRISKS is valid.
# -----------------
# high
# Tool with name pubassistant.ch is valid.
# -----------------
# high
# Tool with name TcellInflamedDetector is valid.
# -----------------
# high
# Tool with name BioAct is valid.
# -----------------
# high
# Tool with name CRIA is valid.
# -----------------
# high
# Tool with name MCDataset is valid.
# -----------------
# high
# Tool with name exp2GO is valid.
# -----------------
# high
# Tool with name MultiGATAE is valid.
# -----------------
# high
# Tool with name FullMonteWeb is valid.
# -----------------
# high
# Tool with name iCVI-ARTMAP is valid.
# -----------------
# high
# Tool with name CRDB is valid.
# -----------------
# high
# Tool with name:PriPath has the errors: {"biotoolsID":["A resource with this ID already exists. bio.tools IDs need to be unique"]}
# Checking if there is an error with the name PriPath ...
# There was a different error
# -----------------
# high
# Tool with name Siglec-9 is valid.
# -----------------
# high
# Tool with name gRDF is valid.
# -----------------
# high
# Tool with name GROMACS-SWAXS is valid.
# -----------------
# Total tools validated: 218 out of a total of: 238
# 20 tools with problems:
# [{'tool_name': 'PPVED', 'error': '{"function":[{"operation":[{},{},{},{"general_errors":["Invalid URI: http://edamontology.org/operation_3923."]}]}]}'}, {'tool_name': 'RNAinsecta', 'error': '{"biotoolsID":["A resource with this ID already exists. bio.tools IDs need to be unique"]}'}, {'tool_name': 'CACSV', 'error': '{"biotoolsID":["A resource with this ID already exists. bio.tools IDs need to be unique"]}'}, {'tool_name': 'Rye', 'error': '{"biotoolsID":["A resource with this ID already exists. bio.tools IDs need to be unique"]}'}, {'tool_name': 'DEPP', 'error': '{"biotoolsID":["A resource with this ID already exists. bio.tools IDs need to be unique"]}'}, {'tool_name': 'OptDesign', 'error': '{"function":[{"operation":[{"general_errors":["Invalid URI: http://edamontology.org/operation_3939."]},{},{}]}]}'}, {'tool_name': 'DeepSARS', 'error': '{"function":[{"operation":[{"general_errors":["Invalid URI: http://edamontology.org/operation_3923."]},{},{},{},{}]}]}'}, {'tool_name': 'StORF-Reporter', 'error': '{"biotoolsID":["A resource with this ID already exists. bio.tools IDs need to be unique"]}'}, {'tool_name': 'ARBRE', 'error': '{"function":[{"operation":[{},{},{},{"general_errors":["Invalid URI: http://edamontology.org/operation_3939."]}]}]}'}, {'tool_name': 'LANDMark', 'error': '{"function":[{"operation":[{"general_errors":["Invalid URI: http://edamontology.org/operation_3923."]},{},{}]}]}'}, {'tool_name': 'Boquila', 'error': '{"biotoolsID":["A resource with this ID already exists. bio.tools IDs need to be unique"]}'}, {'tool_name': 'PyMiner', 'error': '{"function":[{"operation":[{},{},{},{"general_errors":["Invalid URI: http://edamontology.org/operation_3939."]}]}]}'}, {'tool_name': 'PipeCoV', 'error': '{"function":[{"operation":[{},{"general_errors":["Invalid URI: http://edamontology.org/operation_3923."]},{}]}]}'}, {'tool_name': 'Phertilizer', 'error': '{"biotoolsID":["A resource with this ID already exists. bio.tools IDs need to be unique"]}'}, {'tool_name': 'DeePiCt', 'error': '{"biotoolsID":["A resource with this ID already exists. bio.tools IDs need to be unique"]}'}, {'tool_name': 'ShrinkCRISPR', 'error': '{"biotoolsID":["A resource with this ID already exists. bio.tools IDs need to be unique"]}'}, {'tool_name': 'SAM', 'error': '{"biotoolsID":["A resource with this ID already exists. bio.tools IDs need to be unique"]}'}, {'tool_name': 'QuasiFlow', 'error': '{"biotoolsID":["A resource with this ID already exists. bio.tools IDs need to be unique"]}'}, {'tool_name': 'UMIcountR', 'error': '{"function":[{"operation":[{"general_errors":["Invalid URI: http://edamontology.org/operation_3923."]},{},{},{}]}]}'}, {'tool_name': 'PriPath', 'error': '{"biotoolsID":["A resource with this ID already exists. bio.tools IDs need to be unique"]}'}]

# %%
tools_prp = identify_preprints(tools_v,preprints_file)    #STEP 4. FROM THOSE VALIDATED, IDENTIFY PREPRINTS. RERUN = FALSE - it's first time we add "is_preprint" flag. More about it in preprints.py file.
# Out:
# Motifizer
# CanSig
# CoDMI
# HGDTI
# KDmarkers
# HiCHub
# TIGER
# IsoAligner
# SiCoDEA
# OGAR
# SHARCQ
# ASTool
# IMPatienT
# TB-Net
# EcoFun-MAP
# SageNet
# CLIN-X
# DeepDNAbP
# Methylartist
# RLTLBO
# BANYAN
# AttentionDTA
# MDGNN
# CRISPRedict
# PolypSeg+
# m5Cpred-XS
# ImmuMethy
# MicrobioSee
# SEACells
# fastman
# AutoScore-Imbalance
# ASQ
# RetroSnake
# ToxPi
# scAEGAN
# DeepBtoD
# Neuroscout
# GlycoQL
# RustNet
# SmGDB
# Onlinemeta
# SISS-Geo
# TITAN
# TubULAR
# HiveRel
# ROADMAPS
# SNARER
# E2Style
# OC_Finder
# citationchaser
# Spiky
# surge
# ZZS similarity tool
# BANKSY
# Pocket2Drug
# IPOscore
# TCR-L
# epiAneufinder
# Rizoma
# MOOD
# ClinicaDL
# DF-SSmVEP
# hemispheR
# MainSEL
# GenMPI
# RRGP
# COPILOT
# iCatcher
# COVID-19-associated ARDS non-viral ARDS
# AutoDesigner
# MILNP
# PeakVI
# DTSyn
# LinQ-View
# WalkIm
# PhenoBERT
# CPIELA
# PCRMS
# MPI-GWAS
# MAPPER
# DeepTMHMM
# DeSmoke-LAP
# MAECI
# MetaRelSubNetVis
# Read2Tree
# PregTox
# GEAR
# CANon
# AI4ACP
# PredNitro
# scTSSR2
# ENDS assumptions
# PanGu Drug Model
# recolorize
# Fast-Higashi
# KMSubtraction
# LIPSHOK
# AJILE12
# MASI
# BiGAMi
# nsink
# TransPhos
# Kalmag
# CSR-Net
# RFPDR
# SSPNet
# FollicleFinder
# ceCLC
# EEG MEG
# CIGER
# MLHC-COVID-19
# CPA-PM
# Gradient-k
# gACSON
# Aegypti-Atlas
# Psitrum
# MISS
# mHealth literacy mHealth literacy
# Gifsy-1 artAB gogB
# DeepDynaTree
# IETIF
# multiplestressR
# TSFD-Net
# STKD
# LuminoCell
# covid-cancer
# SemanticCAP
# GII 2P16 GII 4P16 noroviruses
# DFLM
# TCSP
# AHLS-pred
# funRiceGenes
# CVVB
# SGP
# NEUROeSTIMator
# SE-BLTCNN
# SOKS
# MANNERS-DB
# RLSDSPCA
# CEBA
# RPfam
# FastDMF
# sponge gourd watermelon
# U-RISC
# DWPPI
# CPGL
# Sophora flavescens Kushen decoction
# MetaDR
# GMM-NEA
# TurboBC
# DiaNat-DB
# COVID-19 non-COVID-19 wards Sudan Zambia
# sup- sup
# SPHARM-Net
# WFA-GPU
# HergSPred
# A3D database
# ingrained
# Research COVID-19 air pollution
# rheuma2025
# FateCompass
# CoMI
# Biocode
# FRET-lines
# scMM
# DNE
# Movement Disorders
# eGRM
# AIM
# TMJOAI
# PADF
# SIMUS
# MISP SRH
# Telerehabilitation physical disabilities movement impairment
# Cure VCP Scientific Conference 2021
# Gegen Qinlian Decoction
# MANE
# PicassoNet
# P-FLUX
# BCOVIDOA
# BiWFA
# GDLPA
# iVp iLAE iBF
# switchable CycleGAN
# la readmision por deshidratacion tanto
# MaxSpliZer
# KDM4B
# Antilogic
# HisCoM-Kernel
# subN LiBasub3 subN NaBasub3 subN
# fern phylogeny
# AB-DB
# SOAR
# TurboBFS
# NVivo
# SARS-ANI
# TWIENG
# ConfoundR
# MuLHiTA
# TAGNet
# HFP-QSMGAN
# LightIoT
# AsgeneDB
# LEV4REC
# VIGIRISKS
# pubassistant.ch
# TcellInflamedDetector
# BioAct
# CRIA
# MCDataset
# exp2GO
# MultiGATAE
# FullMonteWeb
# iCVI-ARTMAP
# CRDB
# Siglec-9
# gRDF
# GROMACS-SWAXS
# [{'name': 'CoDMI', 'description': 'Survival analysis using the Covid-Death Mean-Imputation (CoDMI) algorithm.\n\nPurpose: We illustrate a clinical application of Covid-Death Mean-Imputation (CoDMI) algorithm in survival analysis. Material:. and methods. We analyzed 94 patients treated for primary locally advanced rectal cancer (LARC). Overall survival was calculated in months from diagnosis to first event (last follow-up death). Because Covid-19 death events potentially bias survival estimation, to eliminate skewed data due to Covid-19 death events the observed lifetime of Covid-19 cases was replaced by its corresponding expected lifetime in absence of the Covid-19 event using CoDMI algorithm. In a traditional Kaplan-Meier approach, patient died of Covid-19 (DoC) can be: i) excluded to the cohort, or ii) counted as censored (Cen), or iii) considered as died of disease (DoD). CoDMI algorithm offers an additional, more satisfactory option: iv) DoC events are mean-imputed by the Kaplan-Meier estimator\n\n||| HOMEPAGE BROKEN!', 'homepage': 'https://github.com/alef-innovation/codmi', 'function': [{'operation': [{'uri': 'http://edamontology.org/operation_3503', 'term': 'Incident curve plotting'}, {'uri': 'http://edamontology.org/operation_3659', 'term': 'Regression analysis'}]}], 'topic': [{'uri': 'http://edamontology.org/topic_2640', 'term': 'Oncology'}, {'uri': 'http://edamontology.org/topic_3421', 'term': 'Surgery'}, {'uri': 'http://edamontology.org/topic_2269', 'term': 'Statistics and probability'}], 'confidence_flag': 'high', 'editPermission': {'type': 'public'}, 'biotoolsID': 'pub2tools2023__codmi', 'tool_link': 'https://bio-tools-dev.sdu.dk/pub2tools2023__codmi', 'publication': [{'doi': '10.21873/invivo.13043', 'pmid': '36309383', 'pmcid': 'PMC9677754'}], 'publication_link': 'https://doi.org/10.21873/invivo.13043', 'is_preprint': False}, {'name': 'HGDTI', 'description': 'predicting drug-target interaction by using information aggregation based on heterogeneous graph neural network.\n\nBackground In research on new drug discovery, the traditional wet experiment has a long period. Predicting drug-target interaction (DTI) in silico can greatly narrow the scope of search of candidate medications. Excellent algorithm model may be more effective in revealing the potential connection between drug and target in the bioinformatics network composed of drugs, proteins and other related data. Results. In this work, we have developed a heterogeneous graph neural network model, named as HGDTI, which includes a learning phase of network node embedding and a training phase of DTI classification\n\n||| HOMEPAGE BROKEN!', 'homepage': 'http://bioinfo.jcu.edu.cn/hgdti', 'function': [{'operation': [{'uri': 'http://edamontology.org/operation_3436', 'term': 'Aggregation'}, {'uri': 'http://edamontology.org/operation_3454', 'term': 'Phasing'}, {'uri': 'http://edamontology.org/operation_3927', 'term': 'Network analysis'}, {'uri': 'http://edamontology.org/operation_0478', 'term': 'Molecular docking'}]}], 'topic': [{'uri': 'http://edamontology.org/topic_0154', 'term': 'Small molecules'}, {'uri': 'http://edamontology.org/topic_3474', 'term': 'Machine learning'}, {'uri': 'http://edamontology.org/topic_3336', 'term': 'Drug discovery'}, {'uri': 'http://edamontology.org/topic_3373', 'term': 'Drug development'}, {'uri': 'http://edamontology.org/topic_2275', 'term': 'Molecular modelling'}], 'publication': [{'doi': '10.1186/S12859-022-04655-5', 'pmid': '35413800', 'pmcid': 'PMC9004085'}], 'credit': [{'name': 'Xuan Xiao', 'email': 'jdzxiaoxuan@163.com', 'typeEntity': 'Person'}], 'confidence_flag': 'high', 'editPermission': {'type': 'public'}, 'biotoolsID': 'pub2tools2023__hgdti', 'tool_link': 'https://bio-tools-dev.sdu.dk/pub2tools2023__hgdti', 'publication_link': 'https://doi.org/10.1186/S12859-022-04655-5', 'is_preprint': False}, {'name': 'KDmarkers', 'description': 'A biomarker database for investigating epigenetic methylation and gene expression levels in Ka ...
# There are 48 preprints and 170 pubs in tools
# There are 246 preprints in the json file. Checking if something was published.....
# HISTA
# TreeProfiler
# GametesOmics
# GammaGateR
# GAUSS
# UNNT
# BaRDIC
# CROTONdb
# Cell4D
# MAGPIE
# MolPhase
# RapTCR
# SMARTdb
# 3Dmapper
# MacaqueNet
# plasmidEC
# ASBAR
# bistro
# GIA
# iQC
# PMTPred
# Omix
# AITeQ
# microbiomedataset
# Localgini
# EpiSegMix
# MoTR
# pyHiM
# HILAMA
# OpenCell
# omicsMIC
# ASTA-P
# ACE
# Allo
# QInfoMating
# HLAfreq
# DPKS
# ssREAD
# PTMNavigator
# IMPALA
# MPDS
# CAMPER
# starTracer
# CellsFromSpace
# CBGTPy
# VDI
# NetAn
# eMIND
# SpatialPrompt
# Retro-MTGR
# NCBench
# GeneSetR
# CONORM
# MUSTANG
# evopython
# hART
# phylociraptor
# Monkeybread
# HAVAC
# Cfold
# simmr
# AICOM-MP
# Mycotools
# SurvBal
# Het-PR
# ANMS
# SeqVerify
# SCP Viz
# magpie
# VData
# ONeSAMP 3.0
# ALL-Sum
# PubNavigator
# rotate
# InstaNovo
# SCancerRNA
# PyHFO
# SuperFeat
# MatchMaps
# tidytcells
# MIGRENE
# AutoBA
# RCoV19
# Virseqimprover
# Causal Cookbook
# GB99dms
# DNS
# UNI
# AFITBin
# ProteinFlow
# inDrops-2
# FL-VLD
# EXtra-Xwiz
# cellatlas
# MLPER
# MLDAAPP
# MRMCsamplesize
# richPathR
# OpenToolFlux
# MetFinder
# CellPolaris
# WCRC-25
# LCLUC
# Autometa
# DevCCF
# PepCNN
# knee OA
# Cell2Sentence
# ZEPPI
# candy darter
# BAllCools
# MocFormer
# bamSliceR
# iLEC-DNA
# intNMF
# ScreenDOP
# FairMobi-Net
# ZeptoCTC
# ReproduceMe
# InARes
# QPPLab
# SIDERITE
# BAllC
# MammalMethylClock
# U-Flow
# GROMACS-CIF
# BayesKAT
# VIBES
# admix-kit
# Tool admix-kit has a published version. Changing from 10.1101/2023.09.30.560263 to 10.1093/bioinformatics/btae148
# Tool admix-kit has a published version. Changing from 10.1101/2023.09.30.560263 to 38490256
# diplo-locus
# TARO
# cellPLATO
# PhysiCell Studio
# APOLLO
# gaiaAssociation
# skDER
# FluxNorm
# TRILL
# PFP-FM
# PhyGCN
# SOCfinder
# protoSpaceJAM
# Multioviz
# OMEinfo
# Tool OMEinfo has a published version. Changing from 10.1101/2023.10.23.563576 to 10.1093/bioadv/vbae025
# Tool OMEinfo has a published version. Changing from 10.1101/2023.10.23.563576 to 38456126
# MDMD
# AP-LASR
# Pindel-TD
# Segzoo
# PyDecNef
# PMGmap
# AnophelesModel
# BTR
# NAMERS
# NeoHeadHunter
# MSIsensor-RNA
# Nphos
# OncoReport
# sincFold
# TEC-miTarget
# MTGCL
# ABIapp
# BATTER
# LAVASET
# PREVIC
# PhysioFit
# GenomeSpy
# MetaQuad
# Tool MetaQuad has a published version. Changing from 10.1101/2023.10.09.561628 to 10.1093/bioadv/vbae030
# Tool MetaQuad has a published version. Changing from 10.1101/2023.10.09.561628 to 38476299
# TEPEAK
# Ocelli
# 3DVascNet
# MSA_Limit
# cellContrast
# HIV-DRIVES
# MCHelper
# Rummagene
# ReporterScore
# TreePPL
# AleRax
# NanoLAS
# STEGO
# Listi Wiki
# CUDASW++4.0
# TEclass2
# phyloKRR
# EPDRNA
# Tool EPDRNA has a published version. Changing from 10.21203/RS.3.RS-3476519/V1 to 10.1007/s10930-024-10183-3
# Tool EPDRNA has a published version. Changing from 10.21203/RS.3.RS-3476519/V1 to 38491248
# NeuroMotion
# STew
# READi-Dem
# PitArray
# CellPie
# MADAME
# scRANK
# SiamEEGNet
# Graphite
# DynaMight
# SODA
# AgroNT
# PDB NextGen Archive
# TreeArchTraits
# cubeVB
# NIEND
# plastiC
# ColoRecPred
# NanoBERTa-ASP
# SeqPHASE
# Capricorn
# ConfluentFUCCI
# dismo
# immuno-cross
# CIViCutils
# climetrics
# GraphR
# RESIRE-V
# COINSTAC
# TopoRoot+
# bsAbs
# KmerSV
# AdaptiX
# FedGMMAT
# scDiff
# PhysiMeSS
# ORACLE
# ARPALData
# MIC-SQTL
# gtfsort
# AID-HS
# DiabetIA
# BFF
# TOLGAN
# KIET Annual Report
# SaProt
# VRP assembler
# Kairos
# VAE
# Int and in
# pyTME
# EBP
# AngoraPy
# CytoPipeline
# Nanotope
# FedRDR
# HSQC2STRUC
# StrastiveVI
# PhyloAcc-C
# DepMap
# scBoolSeq
# [{'name': 'admix-kit', 'description': 'An Integrated Toolkit and Pipeline for Genetic Analyses of Admixed Populations.\n\nSummary Admixed populations, with their unique and diverse genetic backgrounds, are often underrepresented in genetic studies. This oversight not only limits our understanding but also exacerbates existing health disparities. One major barrier has been the lack of efficient tools tailored for the special challenges of genetic study of admixed populations. Here, we present admix-kit, an integrated toolkit and pipeline for genetic analyses of admixed populations. Admix-kit implements a suite of methods to facilitate genotype and phenotype simulation, association testing, genetic architecture inference, and polygenic scoring in admixed populations. Availability and implementation. Admix-kit package is open-source and available at https: github.com KangchengHou admix-kit. Additionally, users can use the pipeline designed for admixed genotype simulation available at https: github.com UW-GAC admix-kit_workflow', 'homepage': 'https://github.com/KangchengHou/admix-kit', 'function': [{'operation': [{'uri': 'http://edamontology.org/operation_3196', 'term': 'Genotyping'}, {'uri': 'http://edamontology.org/operation_3920', 'term': 'DNA testing'}, {'uri': 'http://edamontology.org/operation_0244', 'term': 'Simulation analysis'}]}], 'topic': [{'uri': 'http://edamontology.org/topic_0625', 'term': 'Genotype and phenotype'}, {'uri': 'http://edamontology.org/topic_3056', 'term': 'Population genetics'}, {'uri': 'http://edamontology.org/topic_0769', 'term': 'Workflows'}], 'language': ['Python'], 'link': [{'url': 'https://github.com/UW-GAC/admix-kit_workflow', 'type': ['Repository']}], 'credit': [{'name': 'Kangcheng Hou', 'email': 'houkc@ucla.edu', 'typeEntity': 'Person'}, {'name': 'Bogdan Pasaniuc', 'email': 'pasaniuc@ucla.edu', 'typeEntity': 'Person'}, {'name': 'Haoyu Zhang', 'email': 'haoyu.zhang2@nih.gov', 'typeEntity': 'Person'}], 'confidence_flag': 'high', 'editPermission': {'type': 'public'}, 'biotoolsID': 'pub2tools2023__admix-kit', 'tool_link': 'https://bio-tools-dev.sdu.dk/pub2tools2023__admix-kit', 'publication_link': 'https://pubmed.ncbi.nlm.nih.gov/38490256/', 'is_preprint': False, 'publication': [{'doi': '10.1093/bioinformatics/btae148', 'pmid': '38490256'}]}, {'name': 'OMEinfo', 'description': 'Global Geographic Metadata for -omics Experiments.\n\nMicrobiome studies increasingly associate geographical features like rurality and climate types with microbiomes. However, microbiologists bioinformaticians often struggle to access and integrate rich geographical metadata from sources such as GeoTIFFs; and inconsistent definitions of rurality, for example, can hinder cross-study comparisons. To address this, we present OMEinfo, a Python-based tool for automated retrieval of consistent geographical metadata from user-provided location data. OMEinfo leverages open data sources such as the Global Human Settlement Layer, Köppen-Geiger climate classification models, and Open-Data Inventory for Anthropogenic Carbon dioxide, to ensure metadata accuracy and provenance', 'homepage': 'https://github.com/m-crown/OMEinfo/', 'function': [{'operation': [{'uri': 'http://edamontology.org/operation_2422', 'term': 'Data retrieval'}]}], 'topic': [{'uri': 'http://edamontology.org/topic_3697', 'term': 'Microbial ecology'}, {'uri': 'http://edamontology.org/topic_3174', 'term': 'Metagenomics'}, {'uri': 'http://edamontology.org/topic_3277', 'term': 'Sample collections'}], 'language': ['Python'], 'license': 'MIT', 'credit': [{'email': 'matthew.bashton@northumbria.ac.uk', 'typeEntity': 'Person'}], 'confidence_flag': 'high', 'editPermission': {'type': 'public'}, 'biotoolsID': 'pub2tools2023__omeinfo', 'tool_link': 'https://bio-tools-dev.sdu.dk/pub2tools2023__omeinfo', 'publication_link': 'https://pubmed.ncbi.nlm.nih.gov/38456126/', 'is_preprint': False, 'publication': [{'doi': '10.1093/bioadv/vbae025', 'pmid': '38456126', 'pmcid': 'PMC10918632'}]} ...
# There are 4 published tools in the json file.
# Updating json.....
# There are 48 preprints in the file after identification

# %%
tools_to_add, tools_left = generate_csv_pub(tools_prp,100) #STEP 5. GENERATE CSV FROM TO_CURATE FIRST PUBLICATIONS. Alternative function - generate_csv_prp will use TO_CURATE first publications and identified preprints (that might be useful in case of coming back to old curation schema (curating all validated tools))
generate_json(tools_left)                                        # STEP 6. GEENRATE TWO JSON FILES FROM TOOLS THAT WON'T BE CURATED. (leftover tools = all tools - to_curate tools). Generates file with preprints and file with publications. File with preprints can be used as input to identify_preprints later. 
#add_tools(tools_to_add, token, http_settings, WRITE_TO_DB)       # STEP 7. ADD TO_CURATE TOOLS TO DEV
# Out:
#  Writing 100 files which is 100 publications to a pub2tools_2022_02.csv
